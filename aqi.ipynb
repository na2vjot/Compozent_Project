# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('city_day.csv')
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.shape
# Out:
# (29531, 16)

# %%
#Creating a dataset only for mumbai city
mumbai= df[df['City'] == 'Mumbai']
mumbai.head()
# Out:
#          City        Date  PM2.5  PM10  NO  NO2    NOx  NH3   CO  SO2  O3  \
# 21855  Mumbai  2015-01-01    NaN   NaN NaN  NaN  27.38  NaN  0.0  NaN NaN
# 21856  Mumbai  2015-01-02    NaN   NaN NaN  NaN  26.20  NaN  0.0  NaN NaN
# 21857  Mumbai  2015-01-03    NaN   NaN NaN  NaN  26.04  NaN  0.0  NaN NaN
# 21858  Mumbai  2015-01-04    NaN   NaN NaN  NaN  25.97  NaN  0.0  NaN NaN
# 21859  Mumbai  2015-01-05    NaN   NaN NaN  NaN  25.18  NaN  0.0  NaN NaN
#
#        Benzene  Toluene  Xylene  AQI AQI_Bucket
# 21855      0.0      0.0     0.0  NaN        NaN
# 21856      0.0      0.0     0.0  NaN        NaN
# 21857      0.0      0.0     0.0  NaN        NaN
# 21858      0.0      0.0     0.0  NaN        NaN
# 21859      0.0      0.0     0.0  NaN        NaN

# %%
mumbai.shape
# Out:
# (2009, 16)

# %% [markdown]
# Data Preprocessing

# %%
mumbai.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5         1225
# PM10          1246
# NO            1242
# NO2           1253
# NOx            499
# NH3           1614
# CO              25
# SO2           1220
# O3            1212
# Benzene        210
# Toluene        993
# Xylene         994
# AQI           1234
# AQI_Bucket    1234
# dtype: int64

# %%
mumbai = mumbai.drop('NH3', axis=1)


print('mode:',mumbai['PM2.5'].mode())
print('mean:',mumbai['PM2.5'].mean())
print('median:',mumbai['PM2.5'].median())
# Out:
# mode: 0    12.33
# 1    12.96
# 2    14.62
# 3    18.67
# 4    19.26
# Name: PM2.5, dtype: float64
# mean: 35.198392857142856
# median: 23.744999999999997

# %%
#df['column_name'].fillna(df['column_name'].mean(), inplace=True)
mumbai['PM2.5']=mumbai['PM2.5'].fillna(mumbai['PM2.5'].median())

# %%
print('mode:',mumbai['PM10'].mode())
print('mean:',mumbai['PM10'].mean())
print('median:',mumbai['PM10'].median())
# Out:
# mode: 0      42.66
# 1      44.55
# 2      45.85
# 3      46.59
# 4      52.48
# 5      52.92
# 6      54.45
# 7      55.60
# 8      67.13
# 9      67.46
# 10     67.74
# 11     75.24
# 12     82.21
# 13     89.58
# 14    108.48
# 15    158.76
# Name: PM10, dtype: float64
# mean: 96.74505897771952
# median: 77.88

# %%
mumbai['PM10']=mumbai['PM10'].fillna(mumbai['PM10'].median())

# %%
print('mode:',mumbai['NO'].mode())
print('mean:',mumbai['NO'].mean())
print('median:',mumbai['NO'].median())
# Out:
# mode: 0    22.59
# Name: NO, dtype: float64
# mean: 31.01413298565841
# median: 25.34

# %%
mumbai['NO']=mumbai['NO'].fillna(mumbai['NO'].median())

# %%
print('mode:',mumbai['NO2'].mode())
print('mean:',mumbai['NO2'].mean())
print('median:',mumbai['NO2'].median())
# Out:
# mode: 0     9.80
# 1     9.91
# 2    11.30
# 3    15.53
# 4    16.35
# Name: NO2, dtype: float64
# mean: 25.55521164021164
# median: 21.46

# %%
mumbai['NO2']=mumbai['NO2'].fillna(mumbai['NO2'].median())

# %%
print('mode:',mumbai['NOx'].mode())
print('mean:',mumbai['NOx'].mean())
print('median:',mumbai['NOx'].median())

mumbai['NOx']=mumbai['NOx'].fillna(mumbai['NOx'].median())
# Out:
# mode: 0    18.87
# 1    19.25
# 2    22.96
# 3    23.00
# 4    23.02
# 5    23.05
# 6    26.17
# 7    27.50
# 8    37.14
# 9    57.87
# Name: NOx, dtype: float64
# mean: 55.03879470198676
# median: 41.879999999999995

# %%
print('mode:',mumbai['CO'].mode())
print('mean:',mumbai['CO'].mean())
print('median:',mumbai['CO'].median())

mumbai['CO']=mumbai['CO'].fillna(mumbai['CO'].mean())
# Out:
# mode: 0    0.0
# Name: CO, dtype: float64
# mean: 0.5683618951612904
# median: 0.0

# %%
print('mode:',mumbai['SO2'].mode())
print('mean:',mumbai['SO2'].mean())
print('median:',mumbai['SO2'].median())

mumbai['SO2']=mumbai['SO2'].fillna(mumbai['SO2'].median())
# Out:
# mode: 0     8.57
# 1     8.75
# 2     9.46
# 3    11.08
# 4    11.77
# 5    12.06
# Name: SO2, dtype: float64
# mean: 15.197515842839037
# median: 12.67

# %%
print('mode:',mumbai['O3'].mode())
print('mean:',mumbai['O3'].mean())
print('median:',mumbai['O3'].median())

mumbai['O3']=mumbai['O3'].fillna(mumbai['O3'].mean())
# Out:
# mode: 0    12.88
# 1    15.25
# 2    45.84
# Name: O3, dtype: float64
# mean: 33.058946047678795
# median: 29.62

# %%
print('mode:',mumbai['Benzene'].mode())
print('mean:',mumbai['Benzene'].mean())
print('median:',mumbai['Benzene'].median())

mumbai['Benzene']=mumbai['Benzene'].fillna(mumbai['Benzene'].mean())
# Out:
# mode: 0    0.0
# Name: Benzene, dtype: float64
# mean: 1.0986047804335741
# median: 0.0

# %%
print('mode:',mumbai['Toluene'].mode())
print('mean:',mumbai['Toluene'].mean())
print('median:',mumbai['Toluene'].median())

mumbai['Toluene']=mumbai['Toluene'].fillna(mumbai['Toluene'].mean())
# Out:
# mode: 0    0.0
# Name: Toluene, dtype: float64
# mean: 0.013454724409448816
# median: 0.0

# %%
print('mode:',mumbai['Xylene'].mode())
print('mean:',mumbai['Xylene'].mean())
print('median:',mumbai['Xylene'].median())

mumbai['Xylene']=mumbai['Xylene'].fillna(mumbai['Xylene'].mean())
# Out:
# mode: 0    0.0
# Name: Xylene, dtype: float64
# mean: 0.008009852216748768
# median: 0.0

# %%
print('mode:',mumbai['AQI'].mode())
print('mean:',mumbai['AQI'].mean())
print('median:',mumbai['AQI'].median())

mumbai['AQI']=mumbai['AQI'].fillna(mumbai['AQI'].median())
# Out:
# mode: 0    64.0
# 1    67.0
# 2    90.0
# Name: AQI, dtype: float64
# mean: 105.35225806451614
# median: 91.0

# %%
mumbai.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    1234
# dtype: int64

# %%
mumbai['Date'] = pd.to_datetime(mumbai['Date'])  # Convert to datetime

# Extract year, month, and day as separate columns
mumbai['Year'] = mumbai['Date'].dt.year
mumbai['Month'] = mumbai['Date'].dt.month
mumbai['Day'] = mumbai['Date'].dt.day

# Drop the original 'Date' column
mumbai = mumbai.drop('Date', axis=1)
mumbai = mumbai.drop('AQI_Bucket',axis=1)

# %%
mumbai.head()
# Out:
#          City   PM2.5   PM10     NO    NO2    NOx   CO    SO2         O3  \
# 21855  Mumbai  23.745  77.88  25.34  21.46  27.38  0.0  12.67  33.058946
# 21856  Mumbai  23.745  77.88  25.34  21.46  26.20  0.0  12.67  33.058946
# 21857  Mumbai  23.745  77.88  25.34  21.46  26.04  0.0  12.67  33.058946
# 21858  Mumbai  23.745  77.88  25.34  21.46  25.97  0.0  12.67  33.058946
# 21859  Mumbai  23.745  77.88  25.34  21.46  25.18  0.0  12.67  33.058946
#
#        Benzene  Toluene  Xylene   AQI  Year  Month  Day
# 21855      0.0      0.0     0.0  91.0  2015      1    1
# 21856      0.0      0.0     0.0  91.0  2015      1    2
# 21857      0.0      0.0     0.0  91.0  2015      1    3
# 21858      0.0      0.0     0.0  91.0  2015      1    4
# 21859      0.0      0.0     0.0  91.0  2015      1    5

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Drop 'AQI' and 'City' from features (X)
X = mumbai.drop(['City','AQI'], axis=1)

# Select 'AQI' as target variables (y)
y = mumbai[['AQI']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForest = RandomForestRegressor()

# %%
# Train the model
RandomForest.fit(X_train, y_train)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = RandomForest.predict(X_test)
y_pred
# Out:
# array([107.64,  91.  ,  91.  ,  91.  ,  91.  , 142.63,  91.  ,  91.  ,
#         91.  ,  91.  ,  91.  , 139.4 ,  91.  ,  71.77, 136.35,  58.95,
#         91.  ,  95.32,  91.  ,  99.95,  92.12, 145.93,  91.  ,  91.  ,
#         91.  ,  91.  ,  91.  ,  91.  ,  91.  , 217.22,  91.  ,  67.61,
#         91.  ,  91.  ,  91.  ,  91.  ,  79.21,  54.09,  91.  ,  91.  ,
#         91.72,  91.  ,  91.  ,  89.3 ,  84.98,  91.  ,  97.13,  91.  ,
#        147.51, 215.34, 110.01,  91.  , 105.46,  91.  ,  91.  ,  91.  ,
#         91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,
#        177.3 ,  91.  ,  91.  ,  91.  , 218.81,  91.  ,  91.  ,  91.  ,
#         91.  ,  82.12,  75.66,  91.  ,  91.  ,  91.  ,  64.23,  91.  ,
#        167.23, 192.93,  91.  ,  91.  ,  90.23,  91.  , 160.44,  82.47,
#         64.12,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  , 179.76,
#         93.07,  69.35,  91.  ,  92.11,  91.  ,  91.  ,  91.  , 113.25,
#        140.9 ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  78.2 ,
#         91.  ,  91.  , 134.86,  91.  ,  91.  ,  91.  ,  91.  , 135.45,
#         91.  ,  91.  ,  86.84, 129.48, 102.88,  91.  , 101.62,  91.  ,
#         80.85,  91.  ,  91.  , 182.04, 109.48,  91.  , 161.86,  91.  ,
#         79.66,  91.  ,  59.69,  91.  , 133.95,  91.  ,  91.  ,  91.  ,
#         91.  ,  91.  ,  91.  ,  94.24,  91.  , 113.9 ,  91.  ,  91.  ,
#         59.61,  91.  ,  95.98,  91.  ,  91.19,  91.  ,  91.  ,  78.22,
#         91.  , 153.92,  91.  ,  89.77,  85.15,  91.  ,  92.03,  91.  ,
#        213.81,  91.  ,  91.  ,  90.99,  91.  ,  91.  , 161.95,  91.  ,
#         91.  ,  91.  ,  91.  ,  63.31,  91.  ,  68.72,  59.51, 140.63,
#         91.  , 181.77,  91.  ,  91.  ,  91.  , 132.09,  90.41,  91.  ,
#         68.  ,  91.  ,  94.47,  91.  ,  91.  ,  91.  ,  91.  ,  54.88,
#         91.  ,  91.  ,  91.  ,  91.  , 106.58,  91.  , 136.45,  91.  ,
#         69.65,  91.  ,  91.  ,  78.13,  91.  ,  91.  , 149.42,  91.  ,
#         91.  ,  75.27,  52.71, 103.73,  91.  ,  91.  ,  56.06,  91.53,
#         91.  ,  91.  , 114.99,  62.15,  91.  ,  91.  , 106.28,  91.  ,
#        149.65,  91.  , 111.09,  91.  ,  80.23,  91.  ,  91.  , 211.45,
#         91.  , 141.53, 138.53,  91.  , 180.1 ,  57.15,  98.97,  81.58,
#         54.91,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,  91.  , 224.91,
#         91.  ,  91.  ,  70.3 ,  91.  ,  91.  ,  91.  , 219.87,  91.  ,
#         91.  ,  70.22,  91.  , 111.27,  91.  ,  63.24,  91.  ,  91.  ,
#         61.67,  91.  ,  91.  ,  91.  ,  57.47,  91.  ,  85.18,  51.29,
#         91.  ,  91.  ,  68.17,  91.  , 184.48,  91.  , 100.54,  91.  ,
#         91.  ,  67.81,  88.67,  63.38,  83.25,  99.56,  91.  ,  82.25,
#         91.  ,  91.  ,  91.  ,  91.  ,  68.92, 100.54,  91.  ,  75.34,
#         91.  ,  91.  , 221.72, 167.5 ,  91.  ,  59.96,  64.59,  62.41,
#         91.  ,  91.  , 127.83, 127.94,  91.  , 202.93, 120.83,  91.  ,
#         91.  , 150.72,  91.  ,  91.  ,  91.  , 141.1 ,  91.  ,  68.43,
#         91.  ,  91.  ,  62.53,  91.  ,  91.  ,  91.  , 209.08,  64.93,
#        103.85,  70.35, 122.83, 141.32,  91.  ,  91.  , 139.56,  62.25,
#         91.  , 211.19,  91.  ,  91.  ,  91.  , 136.52,  74.9 ,  63.28,
#         70.92, 106.92,  88.06,  91.  ,  91.  ,  91.  ,  91.  ,  91.  ,
#         91.  ,  91.  ,  91.  ,  91.  , 144.12, 216.23,  91.  ,  91.  ,
#         93.84,  91.  ,  91.93,  49.08,  90.59,  91.  , 109.54,  91.  ,
#         91.  ,  91.  ,  92.84,  91.  ,  75.75,  91.  ,  51.21,  91.  ,
#        104.84,  91.  ,  86.31,  91.  , 134.98,  91.  ,  91.  ,  68.6 ,
#         91.  ,  91.  ,  55.38,  91.  ,  91.  ,  91.  ,  59.14,  91.  ,
#         66.18,  90.74])

# %%
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

# Calculate R-squared (R²) score
r2 = r2_score(y_test, y_pred)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 117.91366194029848
# R-squared: 0.8990419631035634

# %%
import pickle

# Assuming 'model' is your trained model and 'encoder' is the data encoder
with open('RF.pkl', 'wb') as f:
    pickle.dump(RandomForest, f)
