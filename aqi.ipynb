# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('city_day.csv')
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  01-01-2015    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  02-01-2015    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  03-01-2015    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  04-01-2015    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  05-01-2015    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.shape
# Out:
# (29531, 16)

# %%
#Creating a dataset only for mumbai city
mumbai= df[df['City'] == 'Mumbai']
mumbai.head()
# Out:
#         City        Date  PM2.5   PM10    NO   NO2    NOx    NH3    CO   SO2  \
# 2009  Mumbai  11-03-2020  32.69  47.91  6.99  2.85  11.93  26.64  0.60  4.53
# 2010  Mumbai  12-03-2020  31.21  38.66  7.20  1.27  10.65  25.63  0.56  4.22
# 2011  Mumbai  13-03-2020  38.39  46.68  7.19  0.91  10.37  29.16  0.57  4.46
# 2012  Mumbai  14-03-2020  43.23  50.83  7.14  1.07  10.48  28.95  0.57  4.53
# 2013  Mumbai  15-03-2020  33.82  41.03  7.09  0.36   9.73  28.41  0.48  4.63
#
#         O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 2009  4.48     0.03     0.30     NaN   NaN           NaN
# 2010  2.81     0.01     0.08     NaN  52.0  Satisfactory
# 2011  0.18     0.00     0.00     NaN  60.0  Satisfactory
# 2012  0.41     0.00     0.00     NaN  62.0  Satisfactory
# 2013  0.30     0.00     0.00     NaN  70.0  Satisfactory

# %%
mumbai.shape
# Out:
# (4290, 16)

# %% [markdown]
# Data Preprocessing

# %%
mumbai.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5         1612
# PM10          2983
# NO            1504
# NO2           1516
# NOx            735
# NH3           3340
# CO             209
# SO2           1479
# O3            1555
# Benzene        430
# Toluene       1215
# Xylene        1589
# AQI           1740
# AQI_Bucket    1740
# dtype: int64

# %%
mumbai = mumbai.drop('NH3', axis=1)


print('mode:',mumbai['PM2.5'].mode())
print('mean:',mumbai['PM2.5'].mean())
print('median:',mumbai['PM2.5'].median())
# Out:
# mode: 0     10.46
# 1     12.33
# 2     12.37
# 3     12.93
# 4     12.96
# 5     13.24
# 6     13.97
# 7     14.62
# 8     17.72
# 9     18.67
# 10    19.26
# 11    19.38
# 12    23.72
# 13    24.24
# 14    36.96
# 15    51.00
# 16    51.74
# 17    56.72
# 18    65.06
# Name: PM2.5, dtype: float64
# mean: 84.72627333831218
# median: 52.775000000000006

# %%
#df['column_name'].fillna(df['column_name'].mean(), inplace=True)
mumbai['PM2.5']=mumbai['PM2.5'].fillna(mumbai['PM2.5'].median())

# %%
print('mode:',mumbai['PM10'].mode())
print('mean:',mumbai['PM10'].mean())
print('median:',mumbai['PM10'].median())
# Out:
# mode: 0       6.19
# 1       6.79
# 2       7.84
# 3       9.11
# 4       9.67
# 5       9.88
# 6      12.72
# 7      19.67
# 8      22.30
# 9      24.25
# 10     27.54
# 11     39.11
# 12     39.87
# 13     40.55
# 14     41.95
# 15     42.66
# 16     43.71
# 17     44.55
# 18     45.38
# 19     45.85
# 20     46.59
# 21     47.56
# 22     48.66
# 23     49.54
# 24     51.10
# 25     52.48
# 26     52.92
# 27     54.45
# 28     55.60
# 29     57.84
# 30     60.85
# 31     67.13
# 32     67.46
# 33     67.74
# 34     75.24
# 35     79.10
# 36     81.35
# 37     82.21
# 38     83.39
# 39     89.58
# 40    108.48
# 41    141.65
# 42    158.76
# 43    985.00
# Name: PM10, dtype: float64
# mean: 84.78260137719971
# median: 64.98

# %%
mumbai['PM10']=mumbai['PM10'].fillna(mumbai['PM10'].mean())

# %%
print('mode:',mumbai['NO'].mode())
print('mean:',mumbai['NO'].mean())
print('median:',mumbai['NO'].median())
# Out:
# mode: 0    0.97
# Name: NO, dtype: float64
# mean: 27.918115577889445
# median: 20.33

# %%
mumbai['NO']=mumbai['NO'].fillna(mumbai['NO'].median())

# %%
print('mode:',mumbai['NO2'].mode())
print('mean:',mumbai['NO2'].mean())
print('median:',mumbai['NO2'].median())
# Out:
# mode: 0    3.56
# Name: NO2, dtype: float64
# mean: 29.581355443403027
# median: 22.285

# %%
mumbai['NO2']=mumbai['NO2'].fillna(mumbai['NO2'].median())

# %%
print('mode:',mumbai['NOx'].mode())
print('mean:',mumbai['NOx'].mean())
print('median:',mumbai['NOx'].median())

mumbai['NOx']=mumbai['NOx'].fillna(mumbai['NOx'].median())
# Out:
# mode: 0    0.0
# Name: NOx, dtype: float64
# mean: 45.249648382559776
# median: 33.57

# %%
print('mode:',mumbai['CO'].mode())
print('mean:',mumbai['CO'].mean())
print('median:',mumbai['CO'].median())

mumbai['CO']=mumbai['CO'].fillna(mumbai['CO'].mean())
# Out:
# mode: 0    0.0
# Name: CO, dtype: float64
# mean: 0.9419039451114922
# median: 0.88

# %%
print('mode:',mumbai['SO2'].mode())
print('mean:',mumbai['SO2'].mean())
print('median:',mumbai['SO2'].median())

mumbai['SO2']=mumbai['SO2'].fillna(mumbai['SO2'].median())
# Out:
# mode: 0    5.69
# Name: SO2, dtype: float64
# mean: 18.18061543934543
# median: 11.1

# %%
print('mode:',mumbai['O3'].mode())
print('mean:',mumbai['O3'].mean())
print('median:',mumbai['O3'].median())

mumbai['O3']=mumbai['O3'].fillna(mumbai['O3'].median())
# Out:
# mode: 0    9.87
# Name: O3, dtype: float64
# mean: 33.890936014625225
# median: 26.58

# %%
print('mode:',mumbai['Benzene'].mode())
print('mean:',mumbai['Benzene'].mean())
print('median:',mumbai['Benzene'].median())

mumbai['Benzene']=mumbai['Benzene'].fillna(mumbai['Benzene'].median())
# Out:
# mode: 0    0.0
# Name: Benzene, dtype: float64
# mean: 4.243126943005182
# median: 0.32

# %%
print('mode:',mumbai['Toluene'].mode())
print('mean:',mumbai['Toluene'].mean())
print('median:',mumbai['Toluene'].median())

mumbai['Toluene']=mumbai['Toluene'].fillna(mumbai['Toluene'].median())
# Out:
# mode: 0    0.0
# Name: Toluene, dtype: float64
# mean: 9.483791869918699
# median: 0.74

# %%
print('mode:',mumbai['Xylene'].mode())
print('mean:',mumbai['Xylene'].mean())
print('median:',mumbai['Xylene'].median())

mumbai['Xylene']=mumbai['Xylene'].fillna(mumbai['Xylene'].median())
# Out:
# mode: 0    0.0
# Name: Xylene, dtype: float64
# mean: 3.3647611995557205
# median: 0.42

# %%
print('mode:',mumbai['AQI'].mode())
print('mean:',mumbai['AQI'].mean())
print('median:',mumbai['AQI'].median())

mumbai['AQI']=mumbai['AQI'].fillna(mumbai['AQI'].median())
# Out:
# mode: 0    19.0
# Name: AQI, dtype: float64
# mean: 175.62196078431373
# median: 134.5

# %%
mumbai.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    1740
# dtype: int64

# %%
mumbai['Date'] = pd.to_datetime(mumbai['Date'], errors='coerce')


mumbai['Year'] = mumbai['Date'].dt.year
mumbai['Month'] = mumbai['Date'].dt.month
mumbai['Day'] = mumbai['Date'].dt.day

# Now you can safely convert them to integers if needed
mumbai['Year'] = mumbai['Year'].astype(float)
mumbai['Month'] = mumbai['Month'].astype(float)
mumbai['Day'] = mumbai['Day'].astype(float)

# Drop the original 'Date' column and any unwanted columns (like AQI_Bucket if needed)
mumbai = mumbai.drop('Date', axis=1)

# Optionally, drop AQI_Bucket if not needed
mumbai = mumbai.drop('AQI_Bucket', axis=1)

# %%
mumbai.head()
# Out:
#         City  PM2.5   PM10    NO   NO2    NOx    CO   SO2    O3  Benzene  \
# 2009  Mumbai  32.69  47.91  6.99  2.85  11.93  0.60  4.53  4.48     0.03
# 2010  Mumbai  31.21  38.66  7.20  1.27  10.65  0.56  4.22  2.81     0.01
# 2011  Mumbai  38.39  46.68  7.19  0.91  10.37  0.57  4.46  0.18     0.00
# 2012  Mumbai  43.23  50.83  7.14  1.07  10.48  0.57  4.53  0.41     0.00
# 2013  Mumbai  33.82  41.03  7.09  0.36   9.73  0.48  4.63  0.30     0.00
#
#       Toluene  Xylene    AQI    Year  Month  Day
# 2009     0.30    0.42  134.5  2020.0   11.0  3.0
# 2010     0.08    0.42   52.0  2020.0   12.0  3.0
# 2011     0.00    0.42   60.0     NaN    NaN  NaN
# 2012     0.00    0.42   62.0     NaN    NaN  NaN
# 2013     0.00    0.42   70.0     NaN    NaN  NaN

# %%
mumbai.isnull().sum()
# Out:
# City          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# Year       2604
# Month      2604
# Day        2604
# dtype: int64

# %%
mumbai['Day']=mumbai['Day'].fillna(mumbai['Day'].median())
mumbai['Month']=mumbai['Month'].fillna(mumbai['Month'].median())
mumbai['Year'] = mumbai['Year'].fillna(2019)

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error

# %%
# Drop 'AQI' and 'City' from features (X)
X = mumbai.drop(['City','AQI'], axis=1)

# Select 'AQI' as target variables (y)
y = mumbai[['AQI']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForest = RandomForestRegressor()

# %%
# Train the model
RandomForest.fit(X_train, y_train)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegress
#        134.5       ,  87.945     ,  80.88      , 143.43      ,
#        221.64      , 134.5       ,  70.055     , 134.5       ,
#        134.5       ,  33.285     , 134.5       , 119.425     ,
#        134.5       ,  65.82      , 189.14      , 206.25      ,
#         95.58      , 135.18291667, 134.5       ,  55.585     ,
#         75.005     , 134.5       , 159.82      ,  80.185     ,
#        200.22      , 215.89      ,  85.99      ,  88.7       ,
#         68.78      , 134.5       , 147.105     ,  40.26      ,
#        264.82      , 458.76      , 134.5       , 134.5       ,
#        134.68711854,  56.71      , 134.5       ,  77.56      ,
#        134.68711854, 208.315     , 151.105     , 134.5       ,
#        230.64      , 134.68711854, 251.815     , 134.5       ,
#        134.5       , 134.5       , 209.2       ,  93.29      ,
#        263.075     , 160.485     ,  24.97      , 134.5       ,
#         47.375     , 208.015     , 134.5       , 137.1       ,
#        109.61114464, 298.57      , 379.005     , 134.5       ,
#         98.09      ,  66.01      ,  86.94      , 470.2       ,
#        102.615     , 132.075     , 152.94      ,  21.62      ,
#        334.32      , 178.72      , 134.5       , 134.5       ,
#        212.27      , 134.5       , 268.265     , 375.59      ,
#        325.59      ,  45.34      , 369.84      ,  83.52      ,
#        134.5       , 208.33      ,  50.36      , 105.22      ,
#        134.5       , 134.5       ,  99.24      , 134.5       ,
#        415.57      , 134.5       , 138.095     ,  53.12      ,
#        201.795     , 158.24      , 134.5       , 134.5       ,
#         95.17      ,  62.8       , 134.5       , 134.5       ,
#        134.5       , 283.44      ,  55.06      ,  81.15      ,
#        134.69182582, 160.83      , 151.43      , 134.5       ,
#         56.97      , 171.965     , 134.5       , 169.75      ,
#        134.5       , 151.42      ,  21.495     , 153.07      ,
#        131.52736434, 134.5       , 101.555     , 134.5       ,
#        134.5       ,  97.73      , 134.5       , 212.08      ,
#         34.41      , 134.5       , 412.76      , 252.35      ,
#        383.04      , 134.5       , 402.9       , 140.095     ,
#        128.165     , 134.5       , 198.675     ,  42.74      ,
#        134.5       , 134.5       , 130.26      , 134.5       ,
#         31.97      , 134.5       , 395.215     , 110.195     ,
#         63.87      , 395.95      , 282.835     ,  23.3       ,
#         57.69      , 102.37      , 120.84      , 129.475     ,
#        100.165     , 212.68      , 154.6       , 134.5       ,
#         53.24      , 134.5       , 349.16      , 130.2285344 ,
#        193.82      ,  70.455     , 268.69      , 134.5       ,
#        152.085     ,  90.85      ,  78.585     , 134.5       ,
#        329.195     ,  68.5       ,  93.54      , 134.5       ,
#        134.5       , 134.075     , 165.465     ,  53.535     ,
#        134.5       ,  60.425     , 134.5       , 130.33      ,
#        272.805     , 134.5       ])

# %%
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

# Calculate R-squared (R²) score
r2 = r2_score(y_test, y_pred)
print('R-squared:', r2)

rmse=root_mean_squared_error(y_test,y_pred)
print('Root Mean Squared Error:',rmse)
# Out:
# Mean Squared Error: 589.2315595320962
# R-squared: 0.9411708833922771
# Root Mean Squared Error: 24.274092352384592

# %%
import pickle

# Assuming 'model' is your trained model and 'encoder' is the data encoder
with open('RF.pkl', 'wb') as f:
    pickle.dump(RandomForest, f)
